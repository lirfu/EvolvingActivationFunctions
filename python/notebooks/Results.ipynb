# %%
import matplotlib.pyplot as plt
import numpy as np
import math as m

# %%
def plot(f):
    x = np.arange(-5,5.001,0.01)
    y = [f(i) for i in x]
    
    plt.figure(figsize=(10,4))
    plt.plot(x, y)
    plt.grid()
    plt.show()

# %% [markdown]
# # Noiseless Hamming distance (9 class)

# %% [markdown]
# ## Common function results
#
# #### Common parameter values
# |Parameters|Common values|
# |:---|---|---|
# |epochs_num|10|
# |batch_size|256|
# |normalize_features|true|
# |shuffle_batches|true|
# |batch_norm|true|
# |learning_rate|0.002|
# |decay_rate|0.99|
# |decay_step|1|
# |regularization_coef|1e-4|
# |seed|42|

# %% [markdown]
# #### Grid search parameter configurations
# |Param bundle|epochs_num|learning_rate|regularization_coef|
# |:---|---|---|---|
# |1|5|2e-3|1e-3|
# |2|10|2e-3|1e-3|
# |3|5|1e-3|1e-3|
# |4|10|1e-3|1e-3|
# |5|5|2e-3|1e-4|
# |6|10|2e-3|1e-4|
# |7|5|1e-3|1e-4|
# |8|10|1e-3|1e-4|

# %% [markdown]
# ### Architecture 100
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.947 | 0.932 | 0.912 | 0.922 | 6
# |ReLU6               |0.947 | 0.937 | 0.910 | 0.923 | 6
# |ELU (1)             |0.938 | 0.938 | 0.898 | 0.915 | 6
# |SELU                |0.933 | 0.941 | 0.881 | 0.905 | 6
# |LReLU               |0.948 | 0.936 | 0.913 | 0.923 | 6
# |Thresholded ReLU (1)|0.927 | 0.893 | 0.883 | 0.887 | 5
# |Swish               |0.943 | 0.938 | 0.909 | 0.922 | 6
# |Sigmoid             |0.941 | 0.932 | 0.902 | 0.914 | 6
# |Hard sigmoid        |0.937 | 0.936 | 0.890 | 0.909 | 6
# |tanh                |0.947 | 0.934 | 0.899 | 0.911 | 6
# |Hard tanh           |0.947 | 0.921 | 0.919 | 0.918 | 6
# |Rational tanh       |0.944 | 0.935 | 0.909 | 0.919 | 6
# |Rectified tanh      |0.954 | 0.949 | 0.912 | 0.929 | 6
# |Softmax             |0.947 | 0.940 | 0.898 | 0.917 | 6
# |Softplus            |0.934 | 0.932 | 0.894 | 0.910 | 6
# |Softsign            |0.945 | 0.924 | 0.911 | 0.915 | 6
# |sin                 |**0.963** | 0.965 | 0.935 | **0.949** | 6
# |cos                 |0.960 | 0.957 | 0.931 | 0.943 | 6
# |exp                 |0.907 | 0.911 | 0.864 | 0.884 | 6
# |pow2                |0.930 | 0.906 | 0.885 | 0.895 | 6
# |pow3                |0.935 | 0.934 | 0.894 | 0.911 | 6
# |gauss               |0.954 | 0.943 | 0.923 | 0.932 | 2

# %% [markdown]
# ### Architecture 200
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.948 | 0.921 | 0.931 | 0.924 | 6
# |ReLU6               |0.947 | 0.908 | 0.927 | 0.914 | 6
# |ELU (1)             |0.940 | 0.930 | 0.909 | 0.917 | 6
# |SELU                |0.942 | 0.930 | 0.907 | 0.917 | 6
# |LReLU               |0.947 | 0.905 | 0.929 | 0.913 | 6
# |Thresholded ReLU (1)|0.937 | 0.900 | 0.895 | 0.897 | 6
# |Swish               |0.942 | 0.899 | 0.928 | 0.910 | 6
# |Sigmoid             |0.946 | 0.941 | 0.913 | 0.926 | 6
# |Hard sigmoid        |0.940 | 0.937 | 0.899 | 0.916 | 6
# |tanh                |0.954 | 0.946 | 0.923 | 0.933 | 6
# |Hard tanh           |0.954 | 0.939 | 0.923 | 0.929 | 6
# |Rational tanh       |0.950 | 0.943 | 0.914 | 0.927 | 6
# |Rectified tanh      |0.956 | 0.937 | 0.925 | 0.930 | 6
# |Softmax             |0.950 | 0.939 | 0.914 | 0.926 | 6
# |Softplus            |0.935 | 0.923 | 0.908 | 0.914 | 6
# |Softsign            |0.951 | 0.934 | 0.921 | 0.926 | 6
# |sin                 |**0.964** | 0.966 | 0.935 | **0.949** | 6
# |cos                 |0.960 | 0.955 | 0.937 | 0.945 | 6
# |exp                 |0.911 | 0.905 | 0.870 | 0.886 | 2
# |pow2                |0.931 | 0.914 | 0.881 | 0.896 | 6
# |pow3                |0.938 | 0.931 | 0.893 | 0.908 | 6
# |gauss               |0.960 | 0.948 | 0.942 | 0.945 | 6

# %% [markdown]
# ### Architecture 300
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.942 | 0.923 | 0.919 | 0.920 | 5
# |ReLU6               |0.942 | 0.926 | 0.915 | 0.919 | 5
# |ELU (1)             |0.925 | 0.918 | 0.885 | 0.900 | 5
# |SELU                |0.929 | 0.931 | 0.860 | 0.886 | 6
# |LReLU               |0.942 | 0.923 | 0.920 | 0.920 | 5
# |Thresholded ReLU (1)|0.938 | 0.907 | 0.906 | 0.904 | 5
# |Swish               |0.934 | 0.922 | 0.908 | 0.914 | 5
# |Sigmoid             |0.923 | 0.927 | 0.870 | 0.894 | 5
# |Hard sigmoid        |0.906 | 0.914 | 0.859 | 0.883 | 5
# |tanh                |0.938 | 0.944 | 0.866 | 0.898 | 5
# |Hard tanh           |0.951 | 0.951 | 0.878 | 0.905 | 6
# |Rational tanh       |0.930 | 0.935 | 0.875 | 0.900 | 5
# |Rectified tanh      |0.949 | 0.947 | 0.896 | 0.915 | 5
# |Softmax             |0.951 | 0.951 | 0.897 | 0.919 | 6
# |Softplus            |0.922 | 0.906 | 0.891 | 0.898 | 5
# |Softsign            |0.947 | 0.948 | 0.865 | 0.892 | 6
# |sin                 |**0.964** | 0.965 | 0.938 | **0.951** | 6
# |cos                 |0.960 | 0.958 | 0.935 | 0.946 | 6
# |exp                 |0.912 | 0.899 | 0.846 | 0.860 | 6
# |pow2                |0.926 | 0.889 | 0.871 | 0.877 | 5
# |pow3                |0.936 | 0.942 | 0.879 | 0.907 | 8
# |gauss               |0.954 | 0.947 | 0.910 | 0.924 | 5 (i 1)

# %% [markdown]
# ### Architecture 500
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.953 | 0.911 | 0.940 | 0.924 | 6 (i 8)
# |ReLU6               |0.953 | 0.912 | 0.944 | 0.926 | 6 (i 8)
# |ELU (1)             |0.941 | 0.902 | 0.924 | 0.908 | 6
# |SELU                |0.928 | 0.898 | 0.881 | 0.888 | 8
# |LReLU               |0.950 | 0.932 | 0.931 | 0.932 | 8
# |Thresholded ReLU (1)|0.948 | 0.908 | 0.922 | 0.914 | 6
# |Swish               |0.938 | 0.928 | 0.913 | 0.919 | 8
# |Sigmoid             |0.944 | 0.920 | 0.925 | 0.921 | 6
# |Hard sigmoid        |0.935 | 0.908 | 0.907 | 0.905 | 6
# |tanh                |0.953 | 0.924 | 0.934 | 0.927 | 6
# |Hard tanh           |0.955 | 0.932 | 0.933 | 0.931 | 6
# |Rational tanh       |0.949 | 0.924 | 0.930 | 0.925 | 6
# |Rectified tanh      |0.960 | 0.937 | 0.943 | 0.939 | 6
# |Softmax             |0.952 | 0.942 | 0.919 | 0.930 | 6
# |Softplus            |0.937 | 0.900 | 0.926 | 0.909 | 6
# |Softsign            |0.948 | 0.920 | 0.917 | 0.916 | 6 (i 8)
# |sin                 |**0.962** | 0.965 | 0.937 | **0.950** | 6
# |cos                 |0.961 | 0.950 | 0.942 | 0.946 | 6
# |exp                 |0.909 | 0.907 | 0.887 | 0.895 | 6
# |pow2                |0.932 | 0.912 | 0.899 | 0.904 | 6
# |pow3                |0.938 | 0.926 | 0.911 | 0.918 | 8
# |gauss               |0.961 | 0.951 | 0.946 | 0.948 | 6

# %% [markdown]
# ### Architecture 10-10
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.916 | 0.906 | 0.735 | 0.851 | 4
# |ReLU6               |0.881 | 0.856 | 0.667 | 0.857 | 7
# |ELU (1)             |0.920 | 0.923 | 0.842 | 0.874 | 6
# |SELU                |0.912 | 0.920 | 0.803 | 0.845 | 6
# |LReLU               |0.920 | 0.923 | 0.796 | 0.834 | 6
# |Thresholded ReLU (1)|0.729 | 0.801 | 0.642 | 0.680 | 5
# |Swish               |0.931 | 0.925 | 0.865 | 0.891 | 6
# |Sigmoid             |0.918 | 0.909 | 0.794 | 0.899 | 6
# |Hard sigmoid        |0.891 | 0.885 | 0.742 | 0.851 | 5
# |tanh                |0.909 | 0.889 | 0.694 | 0.890 | 2
# |Hard tanh           |0.917 | 0.905 | 0.768 | 0.880 | 6
# |Rational tanh       |0.898 | 0.864 | 0.699 | 0.879 | 1
# |Rectified tanh      |0.922 | 0.897 | 0.711 | 0.905 | 2 (i 6)
# |Softmax             |0.912 | 0.892 | 0.695 | 0.893 | 5
# |Softplus            |0.923 | 0.936 | 0.858 | 0.890 | 6
# |Softsign            |0.903 | 0.879 | 0.695 | 0.886 | 2
# |sin                 |0.926 | 0.922 | 0.886 | 0.902 | 6
# |cos                 |**0.940** | 0.924 | 0.878 | 0.897 | 6
# |exp                 |0.895 | 0.909 | 0.807 | 0.848 | 8
# |pow2                |0.933 | 0.933 | 0.883 | **0.906** | 6
# |pow3                |0.895 | 0.918 | 0.850 | 0.879 | 2
# |gauss               |0.931 | 0.904 | 0.883 | 0.891 | 2

# %% [markdown]
# ### Architecture 20-20
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.944 | 0.941 | 0.884 | 0.908 | 5
# |ReLU6               |0.941 | 0.926 | 0.845 | 0.874 | 5
# |ELU (1)             |0.937 | 0.944 | 0.886 | 0.911 | 5
# |SELU                |0.935 | 0.939 | 0.883 | 0.908 | 5
# |LReLU               |0.944 | 0.941 | 0.882 | 0.906 | 5
# |Thresholded ReLU (1)|0.868 | 0.843 | 0.828 | 0.835 | 6
# |Swish               |0.948 | 0.952 | 0.901 | 0.923 | 1
# |Sigmoid             |0.938 | 0.914 | 0.905 | 0.908 | 5
# |Hard sigmoid        |0.930 | 0.891 | 0.897 | 0.894 | 5
# |tanh                |0.935 | 0.933 | 0.860 | 0.886 | 5
# |Hard tanh           |0.940 | 0.921 | 0.888 | 0.902 | 5
# |Rational tanh       |0.939 | 0.905 | 0.906 | 0.904 | 5
# |Rectified tanh      |0.921 | 0.889 | 0.717 | 0.904 | 4
# |Softmax             |0.942 | 0.938 | 0.904 | 0.917 | 5
# |Softplus            |0.939 | 0.941 | 0.895 | 0.916 | 5
# |Softsign            |0.937 | 0.923 | 0.906 | 0.914 | 5
# |sin                 |0.953 | 0.944 | 0.923 | **0.932** | 1
# |cos                 |**0.955** | 0.945 | 0.920 | 0.931 | 1
# |exp                 |0.916 | 0.928 | 0.853 | 0.885 | 0
# |pow2                |0.939 | 0.941 | 0.889 | 0.912 | 5
# |pow3                |0.921 | 0.922 | 0.853 | 0.881 | 5
# |gauss               |0.951 | 0.940 | 0.907 | 0.921 | 1

# %% [markdown]
# ### Architecture 30-30
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU|0.952 | 0.953 | 0.895 | 0.919 | 6
# |ReLU6|0.947 | 0.941 | 0.902 | 0.919 | 2
# |ELU (1)|0.948 | 0.951 | 0.905 | 0.926 | 6
# |SELU|0.944 | 0.945 | 0.886 | 0.911 | 6
# |LReLU|0.952 | 0.950 | 0.911 | 0.928 | 6
# |Thresholded ReLU (1)|0.820 | 0.855 | 0.785 | 0.807 | 5
# |Swish|0.955 | 0.949 | 0.925 | 0.936 | 6
# |Sigmoid|0.937 | 0.899 | 0.916 | 0.907 | 6
# |Hard sigmoid|0.939 | 0.939 | 0.880 | 0.905 | 6
# |tanh|0.939 | 0.917 | 0.906 | 0.911 | 8
# |Hard tanh|0.949 | 0.942 | 0.894 | 0.915 | 6
# |Rational tanh|0.933 | 0.913 | 0.887 | 0.896 | 8
# |Rectified tanh|0.925 | 0.898 | 0.717 | 0.909 | 5
# |Softmax|0.951 | 0.952 | 0.911 | 0.929 | 6
# |Softplus|0.947 | 0.948 | 0.914 | 0.929 | 6
# |Softsign|0.942 | 0.914 | 0.913 | 0.911 | 6
# |sin|0.959 | 0.959 | 0.924 | **0.940** | 6
# |cos|**0.960** | 0.952 | 0.930 | **0.940** | 2
# |tan|0.701 | 0.430 | 0.401 | 0.398 | 4
# |exp|0.889 | 0.912 | 0.844 | 0.874 | 1
# |pow2|0.941 | 0.932 | 0.896 | 0.912 | 6
# |pow3|0.934 | 0.941 | 0.875 | 0.903 | 6
# |gauss|0.954 | 0.946 | 0.923 | 0.933 | 2

# %% [markdown]
# ### Architecture 50-50
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU|0.959 | 0.955 | 0.925 | 0.938 | 6
# |ReLU6|0.954 | 0.943 | 0.917 | 0.927 | 2
# |ELU (1)|0.953 | 0.955 | 0.913 | 0.931 | 6
# |SELU|0.949 | 0.952 | 0.905 | 0.925 | 6
# |LReLU|0.954 | 0.949 | 0.919 | 0.933 | 2
# |Thresholded ReLU (1)|0.905 | 0.893 | 0.853 | 0.871 | 5
# |Swish|0.960 | 0.957 | 0.934 | 0.945 | 6
# |Sigmoid|0.940 | 0.911 | 0.923 | 0.914 | 6
# |Hard sigmoid|0.941 | 0.905 | 0.921 | 0.911 | 6
# |tanh|0.951 | 0.945 | 0.895 | 0.914 | 6
# |Hard tanh|0.954 | 0.932 | 0.926 | 0.929 | 6
# |Rational tanh|0.945 | 0.894 | 0.929 | 0.910 | 6
# |Rectified tanh|0.951 | 0.938 | 0.908 | 0.920 | 6 (i 4)
# |Softmax|0.954 | 0.941 | 0.916 | 0.928 | 8
# |Softplus|0.953 | 0.952 | 0.917 | 0.932 | 6
# |Softsign|0.943 | 0.904 | 0.925 | 0.912 | 6
# |sin|0.960 | 0.962 | 0.933 | 0.946 | 8
# |cos|**0.963** | 0.957 | 0.946 | **0.951** | 6
# |tan|0.270 | 0.101 | 0.111 | 0.063 | 1 (nijedan ne valja)
# |exp|0.925 | 0.906 | 0.855 | 0.878 | 8
# |pow2|0.944 | 0.943 | 0.900 | 0.919 | 8
# |pow3|0.929 | 0.942 | 0.859 | 0.895 | 8
# |gauss|0.960 | 0.955 | 0.925 | 0.938 | 4

# %% [markdown]
# ### Architecture 100-100
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.962 | 0.956 | 0.934 | 0.944 | 5
# |ReLU6               |0.958 | 0.955 | 0.929 | 0.940 | 7
# |ELU (1)             |0.956 | 0.934 | 0.933 | 0.931 | 5
# |SELU                |0.953 | 0.937 | 0.937 | 0.935 | 5
# |LReLU               |0.960 | 0.949 | 0.937 | 0.941 | 5 (i 7)
# |Thresholded ReLU (1)|0.955 | 0.920 | 0.931 | 0.922 | 5
# |Swish               |0.959 | 0.955 | 0.926 | 0.938 | 7
# |Sigmoid             |0.947 | 0.946 | 0.913 | 0.928 | 7
# |Hard sigmoid        |0.954 | 0.947 | 0.925 | 0.934 | 5
# |tanh                |0.931 | 0.918 | 0.879 | 0.896 | 5
# |Hard tanh           |0.952 | 0.953 | 0.915 | 0.931 | 7
# |Rational tanh       |0.950 | 0.950 | 0.924 | 0.936 | 7
# |Rectified tanh      |0.956 | 0.932 | 0.921 | 0.925 | 7
# |Softmax             |0.961 | 0.946 | 0.928 | 0.936 | 5
# |Softplus            |0.947 | 0.942 | 0.912 | 0.924 | 7
# |Softsign            |0.948 | 0.915 | 0.929 | 0.922 | 7
# |sin                 |**0.965** | 0.961 | 0.942 | 0.951 | 5
# |cos                 |**0.965** | 0.955 | 0.951 | **0.953** | 5
# |exp                 |0.924 | 0.939 | 0.861 | 0.894 | 2
# |pow2                |0.945 | 0.942 | 0.892 | 0.914 | 7
# |pow3                |0.935 | 0.937 | 0.892 | 0.912 | 0
# |gauss               |0.963 | 0.958 | 0.936 | 0.946 | 7

# %% [markdown]
# ### Architecture 200-200
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.963 | 0.949 | 0.947 | 0.947 | 5
# |ReLU6               |0.963 | 0.950 | 0.935 | 0.941 | 5
# |ELU (1)             |0.958 | 0.937 | 0.939 | 0.936 | 5 (i 7)
# |SELU                |0.953 | 0.921 | 0.941 | 0.928 | 5
# |LReLU               |0.964 | 0.949 | 0.945 | 0.946 | 5
# |Thresholded ReLU (1)|0.942 | 0.937 | 0.880 | 0.902 | 4
# |Swish               |0.961 | 0.939 | 0.944 | 0.940 | 7
# |Sigmoid             |0.953 | 0.934 | 0.936 | 0.934 | 7
# |Hard sigmoid        |0.954 | 0.940 | 0.932 | 0.936 | 7
# |tanh                |0.960 | 0.933 | 0.947 | 0.939 | 5
# |Hard tanh           |0.959 | 0.913 | 0.940 | 0.924 | 7
# |Rational tanh       |0.956 | 0.933 | 0.938 | 0.934 | 7
# |Rectified tanh      |0.955 | 0.919 | 0.931 | 0.921 | 7
# |Softmax             |0.960 | 0.951 | 0.931 | 0.940 | 7
# |Softplus            |0.959 | 0.942 | 0.939 | 0.939 | 5
# |Softsign            |0.959 | 0.929 | 0.941 | 0.934 | 5
# |sin                 |**0.967** | 0.961 | 0.956 | **0.958** | 5
# |cos                 |0.966 | 0.958 | 0.953 | 0.955 | 5
# |exp                 |0.930 | 0.912 | 0.904 | 0.906 | 1
# |pow2                |0.948 | 0.948 | 0.898 | 0.919 | 7
# |pow3                |0.946 | 0.944 | 0.894 | 0.916 | 4
# |gauss               |0.963 | 0.937 | 0.949 | 0.943 | 5

# %% [markdown]
# ### Architecture 10-10-10
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.931 | 0.933 | 0.894 | 0.912 | 6
# |ReLU6               |0.932 | 0.939 | 0.883 | 0.907 | 2
# |ELU (1)             |0.931 | 0.942 | 0.884 | 0.910 | 6
# |SELU                |0.931 | 0.932 | 0.844 | 0.868 | 6
# |LReLU               |0.933 | 0.936 | 0.895 | 0.913 | 2
# |Thresholded ReLU (1)|0.724 | 0.838 | 0.602 | 0.696 | 5
# |Swish               |0.935 | 0.940 | 0.902 | **0.919** | 2 (i 6)
# |Sigmoid             |0.881 | 0.868 | 0.671 | 0.865 | 7
# |Hard sigmoid        |0.907 | 0.881 | 0.868 | 0.871 | 6
# |tanh                |0.907 | 0.905 | 0.743 | 0.860 | 4
# |Hard tanh           |0.915 | 0.888 | 0.696 | 0.891 | 5
# |Rational tanh       |0.912 | 0.890 | 0.683 | 0.883 | 5
# |Rectified tanh      |0.913 | 0.890 | 0.700 | 0.895 | 8
# |Softmax             |0.933 | 0.936 | 0.882 | 0.905 | 6
# |Softplus            |0.929 | 0.944 | 0.882 | 0.910 | 6
# |Softsign            |0.926 | 0.919 | 0.880 | 0.896 | 6 (i 8)
# |sin                 |0.944 | 0.933 | 0.886 | 0.905 | 2
# |cos                 |**0.950** | 0.951 | 0.891 | 0.916 | 6
# |exp                 |0.891 | 0.900 | 0.801 | 0.842 | 3
# |pow2                |0.936 | 0.941 | 0.878 | 0.906 | 2
# |pow3                |0.904 | 0.905 | 0.794 | 0.836 | 2
# |gauss               |0.943 | 0.940 | 0.892 | 0.910 | 2

# %% [markdown]
# ### Architecture 30-30-30
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU|**0.959** | 0.956 | 0.932 | 0.943 | 6
# |ReLU6|0.956 | 0.949 | 0.932 | 0.939 | 8
# |ELU (1)|0.952 | 0.944 | 0.925 | 0.933 | 6
# |SELU|0.951 | 0.938 | 0.929 | 0.933 | 6
# |LReLU| 0.958 | 0.958 | 0.929 | 0.942 | 6
# |Thresholded ReLU (1)|0.867 | 0.881 | 0.848 | 0.862 | 8 (raste!?)
# |Swish|0.960 | 0.954 | 0.936 | **0.944** | 6
# |Sigmoid|0.936 | 0.919 | 0.899 | 0.907 | 8
# |Hard sigmoid| 0.941 | 0.914 | 0.918 | 0.915 | 6
# |tanh | 0.945 | 0.909 | 0.914 | 0.911 | 8
# |Hard tanh| 0.943 | 0.940 | 0.899 | 0.916 | 2
# |Rational tanh| 0.932 | 0.906 | 0.717 | 0.913 | 5
# |Rectified tanh|0.939 | 0.925 | 0.900 | 0.911 | 8
# |Softmax|0.954 | 0.948 | 0.912 | 0.927 | 8
# |Softplus|0.952 | 0.949 | 0.921 | 0.933 | 6
# |Softsign|0.919 | 0.908 | 0.879 | 0.886 | 4
# |sin|0.958 | 0.942 | 0.941 | 0.941 | 2
# |cos | 0.958 | 0.962 | 0.915 | 0.936| 6
# |tan|0.686 | 0.429 | 0.395 | 0.395 | 4
# |exp| 0.924 | 0.930 | 0.894 | 0.911 | 4
# |pow2|0.951 | 0.940 | 0.918 | 0.928 | 2
# |pow3|0.919 | 0.932 | 0.870 | 0.895 | 2
# |gauss| 0.959 | 0.949 | 0.920 | 0.931 | 2

# %% [markdown]
# ### Architecture 50-50-50
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU|0.961 | 0.955 | 0.938 | 0.946 | 6
# |ReLU6|0.963 | 0.957 | 0.934 | 0.944 | 6
# |ELU (1)|0.957 | 0.954 | 0.935 | 0.944 | 6
# |SELU|0.952 | 0.952 | 0.925 | 0.936 | 6
# |LReLU| 0.963 | 0.956 | 0.939 | 0.946 | 6
# |Thresholded ReLU (1)|0.899 | 0.901 | 0.863 | 0.878 | 5
# |Swish|**0.964** | 0.957 | 0.943 | **0.949** | 6
# |Sigmoid|0.951 | 0.927 | 0.930 | 0.927 | 6
# |Hard sigmoid| 0.947 | 0.926 | 0.931 | 0.927 | 6
# |tanh | 0.950 | 0.948 | 0.913 | 0.929 | 6
# |Hard tanh| 0.951 | 0.932 | 0.915 | 0.923 | 8
# |Rational tanh| 0.952 | 0.929 | 0.927 | 0.927 | 6
# |Rectified tanh|0.948 | 0.928 | 0.911 | 0.918 | 8
# |Softmax|0.957 | 0.954 | 0.919 | 0.933 | 6
# |Softplus|0.954 | 0.954 | 0.915 | 0.932 | 6
# |Softsign|0.946 | 0.931 | 0.907 | 0.917 | 8
# |sin|0.960 | 0.963 | 0.933 | 0.947 | 6
# |cos |0.963 | 0.959 | 0.938 | 0.948 | 8
# |exp| 0.931 | 0.934 | 0.892 | 0.910 | 1
# |pow2|0.953 | 0.937 | 0.928 | 0.931 | 2
# |pow3|0.930 | 0.941 | 0.829 | 0.874 | 6
# |gauss| 0.956 | 0.951 | 0.910 | 0.927 | 8

# %% [markdown]
# ### Architecture 100-100-100
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.965 | 0.958 | 0.941 | 0.948 | 6
# |ReLU6               |0.964 | 0.961 | 0.936 | 0.947 | 6
# |ELU (1)             |0.962 | 0.950 | 0.938 | 0.942 | 6
# |SELU                |0.959 | 0.940 | 0.941 | 0.938 | 6
# |LReLU               |0.965 | 0.958 | 0.940 | 0.947 | 6
# |Thresholded ReLU (1)|0.933 | 0.933 | 0.903 | 0.917 | 6
# |Swish               |**0.967** | 0.953 | 0.942 | 0.944 | 6
# |Sigmoid             |0.952 | 0.946 | 0.925 | 0.934 | 8
# |Hard sigmoid        |0.949 | 0.933 | 0.930 | 0.930 | 8
# |tanh                |0.956 | 0.943 | 0.920 | 0.929 | 8
# |Hard tanh           |0.957 | 0.937 | 0.935 | 0.935 | 6
# |Rational tanh       |0.954 | 0.937 | 0.931 | 0.934 | 8
# |Rectified tanh      |0.947 | 0.869 | 0.915 | 0.877 | 8
# |Softmax             |0.961 | 0.952 | 0.933 | 0.941 | 6
# |Softplus            |0.959 | 0.946 | 0.923 | 0.931 | 6
# |Softsign            |0.953 | 0.914 | 0.927 | 0.918 | 8
# |sin                 |0.963 | 0.961 | 0.946 | **0.953** | 6
# |cos                 |0.964 | 0.959 | 0.945 | 0.952 | 8
# |exp                 |0.932 | 0.908 | 0.915 | 0.910 | 4
# |pow2                |0.956 | 0.957 | 0.922 | 0.938 | 6
# |pow3                |0.936 | 0.941 | 0.879 | 0.905 | 2
# |gauss               |0.957 | 0.950 | 0.914 | 0.930 | 8

# %% [markdown]
# ### Architecture 200-200-200
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.960 | 0.962 | 0.916 | 0.937 | 5
# |ReLU6               |0.962 | 0.924 | 0.941 | 0.929 | 8
# |ELU (1)             |0.962 | 0.945 | 0.942 | 0.942 | 6
# |SELU                |0.959 | 0.956 | 0.935 | 0.943 | 6
# |LReLU               |**0.966** | 0.953 | 0.947 | 0.949 | 6
# |Thresholded ReLU (1)|0.944 | 0.940 | 0.909 | 0.923 | 5
# |Swish               |0.965 | 0.950 | 0.943 | 0.944 | 8
# |Sigmoid             |0.954 | 0.903 | 0.942 | 0.920 | 8
# |Hard sigmoid        |0.959 | 0.937 | 0.939 | 0.937 | 8
# |tanh                |0.960 | 0.916 | 0.947 | 0.930 | 6
# |Hard tanh           |0.951 | 0.910 | 0.932 | 0.920 | 4
# |Rational tanh       |0.958 | 0.923 | 0.944 | 0.932 | 6
# |Rectified tanh      |0.951 | 0.939 | 0.824 | 0.932 | 3
# |Softmax             |0.959 | 0.943 | 0.930 | 0.934 | 8
# |Softplus            |0.965 | 0.953 | 0.945 | 0.948 | 6
# |Softsign            |0.954 | 0.879 | 0.940 | 0.903 | 6
# |sin                 |0.964 | 0.954 | 0.957 | **0.955** | 8
# |cos                 |0.965 | 0.951 | 0.953 | 0.952 | 4 (i 8)
# |exp                 |0.939 | 0.925 | 0.889 | 0.905 | 3
# |pow2                |0.958 | 0.957 | 0.912 | 0.931 | 6
# |pow3                |0.927 | 0.933 | 0.802 | 0.849 | 1
# |gauss               |0.959 | 0.921 | 0.934 | 0.927 | 6

# %% [markdown]
# ### Architecture 300-300-300
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.961 | 0.961 | 0.927 | 0.941 | 6
# |ReLU6               |0.961 | 0.963 | 0.917 | 0.936 | 8
# |ELU (1)             |0.960 | 0.955 | 0.937 | 0.945 | 6
# |SELU                |0.955 | 0.943 | 0.936 | 0.939 | 6
# |LReLU               |0.959 | 0.956 | 0.931 | 0.942 | 6 (i 8)
# |Thresholded ReLU (1)|0.948 | 0.900 | 0.921 | 0.909 | 5
# |Swish               |0.964 | 0.963 | 0.937 | 0.949 | 6
# |Sigmoid             |0.958 | 0.943 | 0.938 | 0.940 | 8
# |Hard sigmoid        |0.948 | 0.932 | 0.930 | 0.929 | 8
# |tanh                |0.960 | 0.955 | 0.921 | 0.936 | 6
# |Hard tanh           |0.959 | 0.954 | 0.914 | 0.929 | 8 (i 7)
# |Rational tanh       |0.958 | 0.957 | 0.927 | 0.939 | 8
# |Rectified tanh      |0.953 | 0.938 | 0.904 | 0.918 | 7
# |Softmax             |0.960 | 0.941 | 0.933 | 0.936 | 8
# |Softplus            |0.961 | 0.965 | 0.926 | 0.943 | 6 (i 8)
# |Softsign            |0.957 | 0.943 | 0.930 | 0.935 | 8
# |sin                 |**0.965** | 0.962 | 0.940 | **0.950** | 2
# |cos                 |0.964 | 0.960 | 0.936 | 0.947 | 8
# |exp                 |0.927 | 0.876 | 0.847 | 0.844 | 3
# |pow2                |0.954 | 0.933 | 0.914 | 0.920 | 5
# |pow3                |0.944 | 0.945 | 0.823 | 0.859 | 6
# |gauss               |0.960 | 0.937 | 0.920 | 0.926 | 1

# %% [markdown]
# ### Architecture 500-500-500
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.961 | 0.962 | 0.933 | 0.946 | 6
# |ReLU6               |0.950 | 0.949 | 0.918 | 0.931 | 3
# |ELU (1)             |0.958 | 0.953 | 0.939 | 0.945 | 6
# |SELU                |0.953 | 0.936 | 0.939 | 0.937 | 6
# |LReLU               |**0.963** | 0.964 | 0.933 | 0.946 | 8
# |Thresholded ReLU (1)|0.950 | 0.903 | 0.928 | 0.913 | 5
# |Swish               |0.962 | 0.961 | 0.939 | 0.949 | 6
# |Sigmoid             |0.958 | 0.956 | 0.937 | 0.945 | 8
# |Hard sigmoid        |0.956 | 0.951 | 0.937 | 0.943 | 6
# |tanh                |0.955 | 0.949 | 0.917 | 0.930 | 8
# |Hard tanh           |0.954 | 0.946 | 0.898 | 0.914 | 8
# |Rational tanh       |0.958 | 0.952 | 0.936 | 0.943 | 8
# |Rectified tanh      |0.953 | 0.942 | 0.878 | 0.893 | 7
# |Softmax             |0.962 | 0.942 | 0.936 | 0.938 | 8
# |Softplus            |0.960 | 0.960 | 0.938 | **0.947** | 6
# |Softsign            |0.955 | 0.938 | 0.926 | 0.930 | 2
# |sin                 |0.962 | 0.951 | 0.942 | 0.946 | 8
# |cos                 |0.961 | 0.961 | 0.934 | 0.946 | 6
# |exp                 |0.915 | 0.864 | 0.755 | 0.793 | 3
# |pow2                |0.954 | 0.935 | 0.933 | 0.933 | 5
# |pow3                |0.936 | 0.935 | 0.762 | 0.883 | 4
# |gauss               |0.956 | 0.927 | 0.931 | 0.926 | 3

# %% [markdown]
# ### Architecture 100-100-100-100
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |**0.963** | 0.959 | 0.938 | **0.947** | 8
# |ReLU6               |0.962 | 0.957 | 0.934 | 0.944 | 8
# |ELU (1)             |0.959 | 0.961 | 0.935 | 0.946 | 6
# |SELU                |0.955 | 0.947 | 0.936 | 0.941 | 6
# |LReLU               |0.962 | 0.957 | 0.931 | 0.942 | 8
# |Thresholded ReLU (1)|0.921 | 0.909 | 0.877 | 0.882 | 5
# |Swish               |0.953 | 0.941 | 0.940 | 0.939 | 1
# |Sigmoid             |0.947 | 0.912 | 0.938 | 0.924 | 8
# |Hard sigmoid        |0.951 | 0.949 | 0.927 | 0.936 | 6
# |tanh                |0.953 | 0.936 | 0.929 | 0.932 | 8
# |Hard tanh           |0.955 | 0.942 | 0.932 | 0.936 | 8
# |Rational tanh       |0.956 | 0.949 | 0.930 | 0.938 | 8
# |Rectified tanh      |0.940 | 0.925 | 0.814 | 0.918 | 3
# |Softmax             |0.960 | 0.949 | 0.920 | 0.933 | 8
# |Softplus            |0.960 | 0.967 | 0.920 | 0.940 | 6
# |Softsign            |0.950 | 0.933 | 0.929 | 0.930 | 6
# |sin                 |**0.963** | 0.958 | 0.936 | 0.945 | 8
# |cos                 |0.957 | 0.949 | 0.936 | 0.942 | 7
# |exp                 |0.923 | 0.908 | 0.857 | 0.878 | 3
# |pow2                |0.950 | 0.935 | 0.914 | 0.923 | 6
# |pow3                |0.908 | 0.917 | 0.699 | 0.821 | 2
# |gauss               |0.957 | 0.937 | 0.930 | 0.932 | 3

# %% [markdown]
# ### Architecture 200-200-200-200
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.960 | 0.952 | 0.933 | 0.941 | 4
# |ReLU6               |0.961 | 0.961 | 0.924 | 0.940 | 8
# |ELU (1)             |0.961 | 0.963 | 0.932 | 0.946 | 6
# |SELU                |0.953 | 0.952 | 0.929 | 0.939 | 6
# |LReLU               |0.960 | 0.960 | 0.928 | 0.942 | 8
# |Thresholded ReLU (1)|0.943 | 0.919 | 0.903 | 0.904 | 5
# |Swish               |0.961 | 0.965 | 0.933 | **0.947** | 8
# |Sigmoid             |0.955 | 0.950 | 0.936 | 0.942 | 8
# |Hard sigmoid        |0.953 | 0.941 | 0.941 | 0.940 | 6
# |tanh                |0.956 | 0.937 | 0.939 | 0.937 | 6
# |Hard tanh           |0.954 | 0.936 | 0.930 | 0.930 | 8
# |Rational tanh       |0.960 | 0.954 | 0.940 | 0.946 | 6
# |Rectified tanh      |0.954 | 0.924 | 0.843 | 0.935 | 8
# |Softmax             |0.959 | 0.936 | 0.921 | 0.928 | 8
# |Softplus            |0.962 | 0.967 | 0.926 | 0.944 | 6
# |Softsign            |0.956 | 0.946 | 0.928 | 0.936 | 6
# |sin                 |**0.963** | 0.960 | 0.932 | 0.945 | 8
# |cos                 |0.955 | 0.934 | 0.945 | 0.939 | 1
# |exp                 |0.927 | 0.862 | 0.849 | 0.854 | 3
# |pow2                |0.953 | 0.919 | 0.912 | 0.913 | 2
# |pow3                |0.925 | 0.922 | 0.834 | 0.868 | 2
# |gauss               |0.961 | 0.927 | 0.947 | 0.936 | 4

# %% [markdown]
# ### Architecture 300-300-300-300
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.961 | 0.963 | 0.930 | 0.944 | 8
# |ReLU6               |0.962 | 0.952 | 0.932 | 0.939 | 8
# |ELU (1)             |0.959 | 0.958 | 0.936 | 0.946 | 8
# |SELU                |0.951 | 0.940 | 0.928 | 0.933 | 6
# |LReLU               |0.962 | 0.964 | 0.921 | 0.939 | 8
# |Thresholded ReLU (1)|0.950 | 0.941 | 0.928 | 0.933 | 5
# |Swish               |**0.963** | 0.964 | 0.933 | 0.946 | 8
# |Sigmoid             |0.958 | 0.958 | 0.936 | 0.946 | 8
# |Hard sigmoid        |0.954 | 0.941 | 0.939 | 0.938 | 8
# |tanh                |0.950 | 0.926 | 0.941 | 0.932 | 8
# |Hard tanh           |0.960 | 0.952 | 0.917 | 0.930 | 8
# |Rational tanh       |**0.963** | 0.959 | 0.932 | 0.944 | 6
# |Rectified tanh      |0.948 | 0.906 | 0.834 | 0.918 | 6 (i 2)
# |Softmax             |0.962 | 0.947 | 0.925 | 0.934 | 8
# |Softplus            |**0.963** | 0.965 | 0.934 | **0.947** | 6
# |Softsign            |0.955 | 0.934 | 0.929 | 0.929 | 6
# |sin                 |0.960 | 0.950 | 0.936 | 0.942 | 8
# |cos                 |0.956 | 0.940 | 0.941 | 0.939 | 2
# |exp                 |0.929 | 0.837 | 0.751 | 0.781 | 4
# |pow2                |0.952 | 0.918 | 0.902 | 0.909 | 4
# |pow3                |0.925 | 0.919 | 0.742 | 0.861 | 6
# |gauss               |0.955 | 0.936 | 0.924 | 0.928 | 3

# %% [markdown]
# ### Architecture 30-30, split 80/20
#
# Best function: <br>
# $sin ((x - 0.7580365993685689) \cdot 0.7580365993685689)$
#
# Evolution:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.958 | 0.953 | 0.950 | 0.951
#
# Re-tested on official split:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.961 | 0.949 | 0.950 | 0.949

# %%
plot(lambda x: m.sin((x-0.7580365993685689)*0.7580365993685689))

# %% [markdown]
# ### Architecture 30-30, split 60/40
#
# Best function: <br>
# $\sin (\cos ( (\sin (\cos (0.9815578450294762)) + x)))$
#
# Evolution:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.957 | 0.954 | 0.935 | 0.944
#
# Re-tested on official split:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.960 | 0.948 | 0.944 | 0.945

# %%
plot(lambda x: m.sin(m.cos((m.sin(m.cos(0.9815578450294762))+x))))

# %% [markdown]
# ### Architecture 30-30, split 40/60
#
# Best function: <br>
# $\sin(\sin(x))$
#
# Evolution:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.951 | 0.946 | 0.927 | 0.935
#
# Re-tested on official split:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.959 | 0.948 | 0.941 | 0.944

# %%
plot(lambda x: m.sin(m.sin(x)))

# %% [markdown]
# ### Architecture 25-25-25, split 80/20
#
# Best function: <br>
# $\min (\min (0.7782706343070911,0.6547420655094701),x)$
#
#
# Evolution:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.946 | 0.948 | 0.942 | 0.945
#
# Re-tested on official split:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.950 | 0.923 | 0.941 | 0.932

# %%
plot(lambda x: min(min(0.7782706343070911,0.6547420655094701), x))

# %% [markdown]
# # Noiseless byte prediction (256 class)

# %% [markdown]
# ## Common function results
#
# #### Common parameter values
# |Parameters|Common values|
# |:---|---|---|
# |epochs_num|10|
# |batch_size|256|
# |normalize_features|true|
# |shuffle_batches|true|
# |batch_norm|true|
# |learning_rate|0.002|
# |decay_rate|0.99|
# |decay_step|1|
# |regularization_coef|1e-4|
# |seed|42|

# %% [markdown]
# #### Grid search parameter configurations
# |Param bundle|epochs_num|learning_rate|regularization_coef|
# |:---|---|---|---|
# |1|5|2e-3|1e-3|
# |2|10|2e-3|1e-3|
# |3|5|1e-3|1e-3|
# |4|10|1e-3|1e-3|
# |5|5|2e-3|1e-4|
# |6|10|2e-3|1e-4|
# |7|5|1e-3|1e-4|
# |8|10|1e-3|1e-4|

# %% [markdown]
# ### Architecture 200
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.463 | 0.485 | 0.464 | 0.450 | 6
# |ReLU6               |0.465 | 0.486 | 0.465 | 0.452 | 6
# |ELU (1)             |0.443 | 0.466 | 0.444 | 0.427 | 6
# |SELU                |0.425 | 0.447 | 0.426 | 0.408 | 6
# |LReLU               |0.462 | 0.483 | 0.463 | 0.448 | 6
# |Thresholded ReLU (1)|0.360 | 0.377 | 0.358 | 0.349 | 5
# |Swish               |0.464 | 0.486 | 0.465 | 0.451 | 6
# |Sigmoid             |0.440 | 0.462 | 0.440 | 0.425 | 6
# |Hard sigmoid        |0.402 | 0.428 | 0.402 | 0.385 | 6
# |tanh                |0.471 | 0.493 | 0.471 | 0.457 | 6
# |Hard tanh           |0.467 | 0.485 | 0.468 | 0.453 | 6
# |Rational tanh       |0.454 | 0.476 | 0.455 | 0.439 | 6
# |Rectified tanh      |0.491 | 0.515 | 0.492 | 0.479 | 6
# |Softmax             |0.480 | 0.497 | 0.481 | 0.468 | 6
# |Softplus            |0.436 | 0.461 | 0.437 | 0.421 | 6
# |Softsign            |0.461 | 0.481 | 0.461 | 0.446 | 6
# |sin                 |0.531 | 0.544 | 0.532 | 0.524 | 6
# |cos                 |**0.532** | 0.542 | 0.533 | **0.526** | 6
# |exp                 |0.406 | 0.437 | 0.406 | 0.393 | 6
# |pow2                |0.444 | 0.459 | 0.445 | 0.434 | 6
# |pow3                |0.454 | 0.473 | 0.455 | 0.443 | 6
# |gauss               |0.521 | 0.533 | 0.521 | 0.515 | 6

# %% [markdown]
# ### Architecture 300
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.473 | 0.491 | 0.474 | 0.462 | 6
# |ReLU6               |0.472 | 0.491 | 0.473 | 0.462 | 6
# |ELU (1)             |0.446 | 0.471 | 0.447 | 0.432 | 6
# |SELU                |0.428 | 0.453 | 0.429 | 0.411 | 6
# |LReLU               |0.473 | 0.490 | 0.474 | 0.462 | 6
# |Thresholded ReLU (1)|0.375 | 0.384 | 0.375 | 0.362 | 5
# |Swish               |0.471 | 0.490 | 0.472 | 0.459 | 6
# |Sigmoid             |0.445 | 0.466 | 0.446 | 0.430 | 6
# |Hard sigmoid        |0.405 | 0.430 | 0.406 | 0.386 | 6
# |tanh                |0.484 | 0.503 | 0.485 | 0.470 | 6
# |Hard tanh           |0.479 | 0.500 | 0.479 | 0.465 | 6
# |Rational tanh       |0.463 | 0.484 | 0.464 | 0.448 | 6
# |Rectified tanh      |0.502 | 0.522 | 0.503 | 0.493 | 6
# |Softmax             |0.485 | 0.495 | 0.485 | 0.475 | 6
# |Softplus            |0.440 | 0.462 | 0.440 | 0.425 | 6
# |Softsign            |0.466 | 0.490 | 0.467 | 0.451 | 6
# |sin                 |**0.546** | 0.554 | 0.547 | **0.539** | 6
# |cos                 |0.537 | 0.543 | 0.537 | 0.531 | 6
# |exp                 |0.408 | 0.433 | 0.409 | 0.398 | 8
# |pow2                |0.440 | 0.450 | 0.440 | 0.433 | 8
# |pow3                |0.462 | 0.480 | 0.463 | 0.452 | 6
# |gauss               |0.527 | 0.535 | 0.528 | 0.520 | 6

# %% [markdown]
# ### Architecture 500
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.476 | 0.498 | 0.476 | 0.465 | 6
# |ReLU6               |0.474 | 0.494 | 0.474 | 0.463 | 6
# |ELU (1)             |0.437 | 0.463 | 0.438 | 0.421 | 6
# |SELU                |0.420 | 0.452 | 0.421 | 0.403 | 6
# |LReLU               |0.474 | 0.495 | 0.474 | 0.463 | 6
# |Thresholded ReLU (1)|0.403 | 0.412 | 0.403 | 0.395 | 6
# |Swish               |0.470 | 0.489 | 0.471 | 0.459 | 6
# |Sigmoid             |0.435 | 0.469 | 0.436 | 0.419 | 6
# |Hard sigmoid        |0.389 | 0.418 | 0.390 | 0.369 | 6
# |tanh                |0.480 | 0.506 | 0.482 | 0.466 | 6
# |Hard tanh           |0.474 | 0.503 | 0.475 | 0.459 | 6
# |Rational tanh       |0.455 | 0.485 | 0.456 | 0.441 | 6
# |Rectified tanh      |0.506 | 0.528 | 0.507 | 0.495 | 6
# |Softmax             |0.492 | 0.502 | 0.493 | 0.483 | 6
# |Softplus            |0.430 | 0.454 | 0.430 | 0.414 | 6
# |Softsign            |0.464 | 0.494 | 0.465 | 0.449 | 6
# |sin                 |**0.550** | 0.560 | 0.551 | **0.544** | 6
# |cos                 |0.525 | 0.532 | 0.525 | 0.519 | 6
# |exp                 |0.406 | 0.429 | 0.407 | 0.395 | 8
# |pow2                |0.436 | 0.447 | 0.436 | 0.428 | 8
# |pow3                |0.458 | 0.478 | 0.460 | 0.447 | 6 (i 8)
# |gauss               |0.522 | 0.532 | 0.523 | 0.516 | 6

# %% [markdown]
# ### Architecture 10-10
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.306 | 0.306 | 0.306 | 0.286 | 5
# |ReLU6               |0.309 | 0.305 | 0.309 | 0.288 | 5
# |ELU (1)             |0.327 | 0.325 | 0.327 | 0.309 | 5
# |SELU                |0.322 | 0.323 | 0.323 | 0.300 | 5
# |LReLU               |0.305 | 0.306 | 0.305 | 0.285 | 5
# |Thresholded ReLU (1)|0.018 | 0.375 | 0.019 | 0.311 | 0
# |Swish               |**0.345** | 0.339 | 0.345 | **0.323** | 5
# |Sigmoid             |0.328 | 0.331 | 0.329 | 0.308 | 5
# |Hard sigmoid        |0.300 | 0.300 | 0.300 | 0.281 | 5
# |tanh                |0.321 | 0.325 | 0.321 | 0.301 | 5
# |Hard tanh           |0.311 | 0.303 | 0.311 | 0.286 | 5
# |Rational tanh       |0.317 | 0.317 | 0.317 | 0.295 | 5
# |Rectified tanh      |0.281 | 0.276 | 0.281 | 0.258 | 5
# |Softmax             |0.306 | 0.306 | 0.307 | 0.286 | 5
# |Softplus            |0.333 | 0.336 | 0.333 | 0.311 | 5
# |Softsign            |0.304 | 0.304 | 0.304 | 0.276 | 5
# |sin                 |**0.345** | 0.355 | 0.345 | **0.323** | 1
# |cos                 |0.298 | 0.293 | 0.298 | 0.276 | 5
# |exp                 |0.305 | 0.322 | 0.307 | 0.289 | 5
# |pow2                |0.288 | 0.294 | 0.287 | 0.272 | 5
# |pow3                |0.309 | 0.318 | 0.309 | 0.290 | 5
# |gauss               |0.279 | 0.276 | 0.279 | 0.253 | 1

# %% [markdown]
# ### Architecture 20-20
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.416 | 0.420 | 0.416 | 0.398 | 6
# |ReLU6               |0.403 | 0.407 | 0.403 | 0.385 | 6
# |ELU (1)             |0.423 | 0.430 | 0.424 | 0.408 | 6
# |SELU                |0.422 | 0.432 | 0.422 | 0.407 | 6
# |LReLU               |0.421 | 0.428 | 0.421 | 0.404 | 6
# |Thresholded ReLU (1)|0.008 | 0.532 | 0.008 | 0.414 | 2
# |Swish               |0.430 | 0.436 | 0.430 | 0.415 | 6
# |Sigmoid             |0.418 | 0.423 | 0.419 | 0.400 | 6
# |Hard sigmoid        |0.407 | 0.413 | 0.407 | 0.392 | 6
# |tanh                |0.415 | 0.422 | 0.416 | 0.398 | 6
# |Hard tanh           |0.421 | 0.427 | 0.421 | 0.404 | 6
# |Rational tanh       |0.422 | 0.429 | 0.423 | 0.406 | 6
# |Rectified tanh      |0.365 | 0.369 | 0.366 | 0.342 | 6
# |Softmax             |0.418 | 0.424 | 0.418 | 0.400 | 6
# |Softplus            |0.420 | 0.425 | 0.420 | 0.404 | 6
# |Softsign            |0.393 | 0.401 | 0.394 | 0.374 | 6 (fali za 5)
# |sin                 |**0.441** | 0.442 | 0.442 | **0.426** | 6
# |cos                 |0.394 | 0.396 | 0.395 | 0.379 | 6
# |exp                 |0.371 | 0.390 | 0.371 | 0.348 | 2
# |pow2                |0.383 | 0.393 | 0.384 | 0.367 | 6
# |pow3                |0.389 | 0.399 | 0.390 | 0.370 | 6
# |gauss               |0.376 | 0.380 | 0.376 | 0.359 | 6

# %% [markdown]
# ### Architecture 30-30
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU| 0.455 | 0.467 | 0.456 | 0.442 | 6
# |ReLU6| 0.454 | 0.466 | 0.455 | 0.440 | 6
# |ELU (1)|0.459 | 0.468 | 0.460 | 0.447 | 6
# |SELU|0.445 | 0.457 | 0.446 | 0.430 | 6
# |LReLU| 0.451 | 0.462 | 0.452 | 0.437 | 6
# |Thresholded ReLU (1)| 0.008 | 0.423 | 0.009 | 0.187 | 2
# |Swish| 0.470 | 0.478 | 0.471 | 0.458 | 6
# |Sigmoid|0.447 | 0.461 | 0.448 | 0.434 | 6
# |Hard sigmoid|0.449 | 0.459 | 0.450 | 0.436 | 6
# |tanh| 0.447 | 0.457 | 0.447 | 0.432 | 6
# |Hard tanh| 0.447 | 0.453 | 0.447 | 0.432 | 6
# |Rational tanh| 0.446 | 0.459 | 0.447 | 0.433 | 6
# |Rectified tanh| 0.401 | 0.406 | 0.402 | 0.380 | 6
# |Softmax| 0.453 | 0.461 | 0.453 | 0.437 | 6
# |Softplus| 0.460 | 0.471 | 0.461 | 0.447 | 6
# |Softsign| 0.424 | 0.434 | 0.425 | 0.408 | 6
# |sin|**0.474** | 0.481 | 0.475 | **0.463** | 6
# |cos|0.441 | 0.444 | 0.441 | 0.426 | 6
# |tan| 0.013 | 0.012 | 0.013 | 0.004 | 4 (ni jedan ne valja)
# |exp|0.412 | 0.433 | 0.412 | 0.396 | 6
# |pow2| 0.441 | 0.451 | 0.442 | 0.428 | 6
# |pow3|0.425 | 0.437 | 0.425 | 0.407 | 6
# |gauss|0.433 | 0.450 | 0.434 | 0.414 | 2 (i 6)

# %% [markdown]
# ### Architecture 50-50
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU|0.484 | 0.493 | 0.485 | 0.471 | 6
# |ReLU6|0.486 | 0.494 | 0.487 | 0.474 | 6
# |ELU (1)| 0.490 | 0.507 | 0.491 | 0.477 | 6
# |SELU|0.483 | 0.498 | 0.483 | 0.469 | 6
# |LReLU|0.486 | 0.499 | 0.487 | 0.474 | 6
# |Thresholded ReLU (1)|0.009 | 0.384 | 0.009 | 0.349 | 2 (ni jedan ne valja)
# |Swish|0.504 | 0.512 | 0.505 | 0.492 | 6
# |Sigmoid|0.479 | 0.492 | 0.480 | 0.465 | 6
# |Hard sigmoid|0.473 | 0.487 | 0.474 | 0.458  | 6
# |tanh|0.483 | 0.498 | 0.484 | 0.470 | 6
# |Hard tanh|0.480 | 0.493 | 0.481 | 0.465 | 6
# |Rational tanh|0.482 | 0.499 | 0.483 | 0.470 | 6
# |Rectified tanh|0.455 | 0.462 | 0.456 | 0.439 | 6 (i 4)
# |Softmax|0.485 | 0.497 | 0.487 | 0.472 | 6
# |Softplus|0.488 | 0.502 | 0.490 | 0.475 | 6
# |Softsign|0.472 | 0.483 | 0.472 | 0.457  | 6
# |sin|**0.508** | 0.516 | 0.509 | **0.500** | 6
# |cos| 0.482 | 0.490 | 0.483 | 0.472 | 6
# |tan|0.015 | 0.011 | 0.015 | 0.004 | 4 (ni jedan ne valja)
# |exp| 0.425 | 0.457 | 0.426 | 0.409 | 6 (i 5)
# |pow2|0.471 | 0.485 | 0.472 | 0.459 | 6
# |pow3|0.466 | 0.483 | 0.467 | 0.452 | 6
# |gauss| 0.479 | 0.485 | 0.480 | 0.467 | 6

# %% [markdown]
# ### Architecture 100-100
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.518 | 0.533 | 0.519 | 0.508 | 6
# |ReLU6               |0.517 | 0.533 | 0.518 | 0.507 | 6
# |ELU (1)             |0.509 | 0.527 | 0.510 | 0.495 | 6
# |SELU                |0.496 | 0.513 | 0.497 | 0.481 | 6
# |LReLU               |0.517 | 0.532 | 0.518 | 0.506 | 6
# |Thresholded ReLU (1)|0.266 | 0.290 | 0.265 | 0.251 | 5
# |Swish               |0.534 | 0.546 | 0.535 | 0.525 | 6
# |Sigmoid             |0.505 | 0.525 | 0.506 | 0.492 | 6
# |Hard sigmoid        |0.487 | 0.508 | 0.488 | 0.474 | 6
# |tanh                |0.519 | 0.541 | 0.521 | 0.508 | 6
# |Hard tanh           |0.509 | 0.534 | 0.510 | 0.497 | 6
# |Rational tanh       |0.511 | 0.535 | 0.512 | 0.499 | 6
# |Rectified tanh      |0.499 | 0.512 | 0.500 | 0.487 | 6 (i 8)
# |Softmax             |0.515 | 0.531 | 0.516 | 0.504 | 6
# |Softplus            |0.509 | 0.528 | 0.510 | 0.495 | 6
# |Softsign            |0.507 | 0.528 | 0.508 | 0.495 | 6
# |sin                 |**0.554** | 0.565 | 0.555 | **0.548** | 6
# |cos                 |0.520 | 0.534 | 0.521 | 0.513 | 6 (i 8)
# |exp                 |0.448 | 0.465 | 0.449 | 0.438 | 8
# |pow2                |0.500 | 0.514 | 0.501 | 0.491 | 6
# |pow3                |0.505 | 0.525 | 0.506 | 0.493 | 6
# |gauss               |0.522 | 0.542 | 0.523 | 0.511 | 2

# %% [markdown]
# ### Architecture 200-200
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.544 | 0.562 | 0.544 | 0.534 | 6
# |ReLU6               |0.544 | 0.562 | 0.544 | 0.535 | 6
# |ELU (1)             |0.521 | 0.550 | 0.522 | 0.511 | 6
# |SELU                |0.510 | 0.539 | 0.511 | 0.497 | 6
# |LReLU               |0.541 | 0.560 | 0.541 | 0.532 | 6
# |Thresholded ReLU (1)|0.010 | 0.410 | 0.010 | 0.462 | 4
# |Swish               |0.543 | 0.559 | 0.543 | 0.534 | 6
# |Sigmoid             |0.525 | 0.548 | 0.526 | 0.514 | 6
# |Hard sigmoid        |0.503 | 0.527 | 0.503 | 0.491 | 6
# |tanh                |0.533 | 0.561 | 0.534 | 0.522 | 6
# |Hard tanh           |0.528 | 0.552 | 0.529 | 0.518 | 6
# |Rational tanh       |0.532 | 0.555 | 0.532 | 0.521 | 6
# |Rectified tanh      |0.528 | 0.545 | 0.529 | 0.518 | 6
# |Softmax             |0.522 | 0.533 | 0.523 | 0.510 | 6
# |Softplus            |0.521 | 0.542 | 0.522 | 0.510 | 6
# |Softsign            |0.522 | 0.550 | 0.523 | 0.510 | 6
# |sin                 |**0.566** | 0.574 | 0.567 | **0.561** | 8
# |cos                 |0.545 | 0.552 | 0.545 | 0.540 | 8
# |exp                 |0.469 | 0.490 | 0.469 | 0.460 | 8
# |pow2                |0.508 | 0.518 | 0.509 | 0.501 | 8
# |pow3                |0.511 | 0.536 | 0.511 | 0.501 | 6
# |gauss               |0.547 | 0.564 | 0.548 | 0.538 | 4

# %% [markdown]
# ### Architecture 30-30-30
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU|0.470 | 0.481 | 0.471 | 0.455 | 6
# |ReLU6|0.470 | 0.477 | 0.470 | 0.455 | 6
# |ELU (1)| 0.479 | 0.490 | 0.480 | 0.466 | 6
# |SELU|0.471 | 0.482 | 0.472 | 0.457 | 6
# |LReLU|0.469 | 0.475 | 0.469 | 0.455 | 6
# |Thresholded ReLU (1)|0.012 | 0.388 | 0.012 | 0.355 | 2 (ni jedan ne valja)
# |Swish|**0.486** | 0.497 | 0.487 | **0.473** | 6
# |Sigmoid|0.475 | 0.486 | 0.476 | 0.463 | 6
# |Hard sigmoid|0.468 | 0.480 | 0.468 | 0.456 | 6
# |tanh|0.460 | 0.471 | 0.462 | 0.446 | 6
# |Hard tanh|0.465 | 0.470 | 0.465 | 0.448 | 6
# |Rational tanh| 0.473 | 0.483 | 0.474 | 0.460 | 6
# |Rectified tanh|0.420 | 0.430 | 0.421 | 0.400 | 6
# |Softmax|0.460 | 0.466 | 0.461 | 0.445 | 6
# |Softplus|0.479 | 0.491 | 0.480 | 0.468 | 6
# |Softsign|0.440 | 0.449 | 0.441 | 0.423 | 6
# |sin|0.482 | 0.487 | 0.482 | 0.470 | 6
# |cos|0.421 | 0.427 | 0.422 | 0.405 | 6
# |tan|0.183 | 0.195 | 0.184 | 0.158 | 4 (ni jedan ne valja)
# |exp|0.380 | 0.415 | 0.381 | 0.364 | 6 (i 8)
# |pow2|0.423 | 0.437 | 0.423 | 0.407 | 6
# |pow3|0.404 | 0.415 | 0.405 | 0.383 | 6
# |gauss|0.404 | 0.411 | 0.405 | 0.388 | 6

# %% [markdown]
# ### Architecture 50-50-50
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.498 | 0.511 | 0.499 | 0.484 | 6
# |ReLU6               |0.497 | 0.511 | 0.498 | 0.483 | 6
# |ELU (1)             |0.496 | 0.511 | 0.496 | 0.485 | 6
# |SELU                |0.493 | 0.506 | 0.493 | 0.480 | 6
# |LReLU               |0.500 | 0.512 | 0.500 | 0.486 | 6
# |Thresholded ReLU (1)|0.010 | 0.419 | 0.010 | 0.444 | 4
# |Swish               |0.517 | 0.527 | 0.517 | 0.504 | 6
# |Sigmoid             |0.494 | 0.511 | 0.495 | 0.481 | 6
# |Hard sigmoid        |0.503 | 0.516 | 0.504 | 0.492 | 6
# |tanh                |0.498 | 0.508 | 0.499 | 0.483 | 6
# |Hard tanh           |0.500 | 0.514 | 0.501 | 0.485 | 6
# |Rational tanh       |0.504 | 0.517 | 0.504 | 0.492 | 6
# |Rectified tanh      |0.448 | 0.465 | 0.449 | 0.429 | 4
# |Softmax             |0.491 | 0.504 | 0.492 | 0.478 | 6
# |Softplus            |0.499 | 0.515 | 0.500 | 0.487 | 6
# |Softsign            |0.478 | 0.491 | 0.479 | 0.462 | 6
# |sin                 |**0.524** | 0.533 | 0.524 | **0.513** | 6
# |cos                 |0.456 | 0.464 | 0.457 | 0.446 | 6
# |exp                 |0.425 | 0.439 | 0.426 | 0.415 | 8
# |pow2                |0.479 | 0.490 | 0.480 | 0.467 | 6
# |pow3                |0.459 | 0.483 | 0.460 | 0.443 | 6
# |gauss               |0.457 | 0.464 | 0.457 | 0.444 | 6

# %% [markdown]
# ### Architecture 100-100-100
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |**0.534** | 0.550 | 0.534 | 0.522 | 6
# |ReLU6               |0.530 | 0.543 | 0.531 | 0.516 | 6
# |ELU (1)             |0.529 | 0.548 | 0.529 | 0.515 | 6
# |SELU                |0.521 | 0.548 | 0.522 | 0.507 | 6
# |LReLU               |0.531 | 0.545 | 0.532 | 0.519 | 6
# |Thresholded ReLU (1)|0.266 | 0.279 | 0.264 | 0.246 | 5
# |Swish               |0.547 | 0.561 | 0.547 | 0.537 | 6
# |Sigmoid             |0.526 | 0.547 | 0.527 | 0.514 | 6
# |Hard sigmoid        |0.515 | 0.534 | 0.516 | 0.504 | 6
# |tanh                |0.521 | 0.538 | 0.522 | 0.507 | 6
# |Hard tanh           |0.519 | 0.537 | 0.520 | 0.506 | 6
# |Rational tanh       |0.533 | 0.552 | 0.534 | 0.522 | 6
# |Rectified tanh      |0.492 | 0.502 | 0.493 | 0.481 | 8
# |Softmax             |0.521 | 0.531 | 0.521 | 0.509 | 6
# |Softplus            |0.532 | 0.550 | 0.533 | 0.520 | 6
# |Softsign            |0.510 | 0.534 | 0.511 | 0.496 | 6
# |sin                 |0.553 | 0.567 | 0.553 | **0.547** | 6
# |cos                 |0.494 | 0.498 | 0.494 | 0.486 | 8
# |exp                 |0.462 | 0.474 | 0.462 | 0.452 | 8
# |pow2                |0.512 | 0.526 | 0.512 | 0.503 | 6
# |pow3                |0.502 | 0.527 | 0.503 | 0.487 | 6
# |gauss               |0.493 | 0.504 | 0.493 | 0.478 | 4

# %% [markdown]
# ### Architecture 200-200-200
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.547 | 0.569 | 0.548 | 0.536 | 6 (i 8)
# |ReLU6               |0.551 | 0.571 | 0.552 | 0.540 | 6
# |ELU (1)             |0.538 | 0.569 | 0.539 | 0.527 | 6
# |SELU                |0.534 | 0.562 | 0.535 | 0.521 | 6
# |LReLU               |0.549 | 0.569 | 0.550 | 0.540 | 6
# |Thresholded ReLU (1)|0.314 | 0.344 | 0.313 | 0.302 | 5
# |Swish               |0.556 | 0.575 | 0.557 | 0.547 | 6
# |Sigmoid             |0.545 | 0.573 | 0.546 | 0.536 | 6
# |Hard sigmoid        |0.536 | 0.563 | 0.536 | 0.523 | 6
# |tanh                |0.538 | 0.555 | 0.539 | 0.528 | 8
# |Hard tanh           |0.537 | 0.557 | 0.538 | 0.526 | 8
# |Rational tanh       |0.544 | 0.569 | 0.545 | 0.534 | 6
# |Rectified tanh      |0.523 | 0.535 | 0.523 | 0.512 | 8
# |Softmax             |0.536 | 0.549 | 0.537 | 0.527 | 6
# |Softplus            |0.545 | 0.568 | 0.546 | 0.533 | 6
# |Softsign            |0.534 | 0.560 | 0.535 | 0.521 | 6
# |sin                 |**0.562** | 0.571 | 0.564 | **0.558** | 8
# |cos                 |0.515 | 0.525 | 0.515 | 0.504 | 4
# |exp                 |0.456 | 0.490 | 0.457 | 0.440 | 4
# |pow2                |0.533 | 0.551 | 0.534 | 0.524 | 6
# |pow3                |0.513 | 0.543 | 0.514 | 0.500 | 6
# |gauss               |0.505 | 0.518 | 0.505 | 0.493 | 4

# %% [markdown]
# ### Architecture 300-300-300
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.554 | 0.580 | 0.555 | 0.547 | 6
# |ReLU6               |0.558 | 0.580 | 0.558 | 0.550 | 6
# |ELU (1)             |0.551 | 0.577 | 0.552 | 0.541 | 6
# |SELU                |0.544 | 0.572 | 0.544 | 0.531 | 6
# |LReLU               |0.558 | 0.582 | 0.558 | 0.549 | 6
# |Thresholded ReLU (1)|0.337 | 0.374 | 0.335 | 0.325 | 5
# |Swish               |**0.568** | 0.586 | 0.569 | **0.562** | 6
# |Sigmoid             |0.552 | 0.579 | 0.553 | 0.540 | 6
# |Hard sigmoid        |0.539 | 0.565 | 0.539 | 0.525 | 6
# |tanh                |0.545 | 0.563 | 0.545 | 0.535 | 8
# |Hard tanh           |0.543 | 0.562 | 0.543 | 0.533 | 8
# |Rational tanh       |0.546 | 0.575 | 0.547 | 0.535 | 6 (i 8)
# |Rectified tanh      |0.531 | 0.549 | 0.532 | 0.521 | 8
# |Softmax             |0.534 | 0.543 | 0.533 | 0.526 | 8
# |Softplus            |0.554 | 0.578 | 0.556 | 0.544 | 6
# |Softsign            |0.536 | 0.563 | 0.537 | 0.526 | 6
# |sin                 |0.564 | 0.587 | 0.564 | 0.553 | 4 (i 8)
# |cos                 |0.511 | 0.528 | 0.511 | 0.501 | 4
# |exp                 |0.469 | 0.492 | 0.470 | 0.461 | 8
# |pow2                |0.533 | 0.547 | 0.534 | 0.527 | 6
# |pow3                |0.522 | 0.549 | 0.524 | 0.512 | 6
# |gauss               |0.512 | 0.527 | 0.513 | 0.502 | 4

# %% [markdown]
# ### Architecture 500-500-500
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.559 | 0.585 | 0.559 | 0.549 | 6
# |ReLU6               |0.553 | 0.577 | 0.554 | 0.545 | 6
# |ELU (1)             |0.553 | 0.583 | 0.554 | 0.543 | 6
# |SELU                |0.548 | 0.581 | 0.548 | 0.536 | 6
# |LReLU               |0.554 | 0.580 | 0.554 | 0.545 | 6
# |Thresholded ReLU (1)|0.381 | 0.413 | 0.380 | 0.369 | 6
# |Swish               |0.553 | 0.578 | 0.554 | 0.545 | 6
# |Sigmoid             |0.553 | 0.580 | 0.552 | 0.541 | 6
# |Hard sigmoid        |0.541 | 0.569 | 0.540 | 0.530 | 6
# |tanh                |0.545 | 0.563 | 0.545 | 0.535 | 8
# |Hard tanh           |0.535 | 0.555 | 0.534 | 0.525 | 8
# |Rational tanh       |0.546 | 0.568 | 0.547 | 0.534 | 8
# |Rectified tanh      |0.543 | 0.566 | 0.544 | 0.533 | 8
# |Softmax             |0.540 | 0.549 | 0.541 | 0.534 | 8
# |Softplus            |0.549 | 0.578 | 0.550 | 0.539 | 6
# |Softsign            |0.549 | 0.582 | 0.549 | 0.534 | 6
# |sin                 |**0.566** | 0.587 | 0.566 | **0.558** | 4
# |cos                 |0.512 | 0.526 | 0.512 | 0.503 | 4
# |exp                 |0.441 | 0.476 | 0.442 | 0.432 | 7
# |pow2                |0.533 | 0.553 | 0.533 | 0.525 | 6 (i 8)
# |pow3                |0.521 | 0.543 | 0.522 | 0.511 | 8
# |gauss               |0.503 | 0.519 | 0.504 | 0.493 | 4

# %% [markdown]
# ### Architecture 100-100-100-100
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.532 | 0.552 | 0.533 | 0.520 | 6
# |ReLU6               |0.534 | 0.550 | 0.535 | 0.522 | 6
# |ELU (1)             |0.532 | 0.553 | 0.533 | 0.519 | 6
# |SELU                |0.527 | 0.550 | 0.527 | 0.511 | 6
# |LReLU               |0.536 | 0.556 | 0.537 | 0.525 | 6
# |Thresholded ReLU (1)|0.251 | 0.274 | 0.249 | 0.234 | 5
# |Swish               |**0.552** | 0.569 | 0.553 | 0.541 | 6
# |Sigmoid             |0.530 | 0.550 | 0.531 | 0.516 | 6
# |Hard sigmoid        |0.522 | 0.544 | 0.523 | 0.508 | 6
# |tanh                |0.525 | 0.538 | 0.526 | 0.514 | 8
# |Hard tanh           |0.523 | 0.532 | 0.524 | 0.513 | 8
# |Rational tanh       |0.527 | 0.547 | 0.527 | 0.512 | 6
# |Rectified tanh      |0.482 | 0.494 | 0.483 | 0.468 | 8
# |Softmax             |0.522 | 0.532 | 0.522 | 0.513 | 8
# |Softplus            |0.541 | 0.560 | 0.542 | 0.529 | 6
# |Softsign            |0.510 | 0.530 | 0.511 | 0.494 | 6
# |sin                 |0.550 | 0.556 | 0.551 | **0.543** | 8
# |cos                 |0.485 | 0.501 | 0.486 | 0.468 | 4
# |exp                 |0.441 | 0.473 | 0.442 | 0.423 | 4
# |pow2                |0.512 | 0.528 | 0.512 | 0.499 | 6
# |pow3                |0.446 | 0.482 | 0.447 | 0.428 | 6
# |gauss               |0.469 | 0.488 | 0.469 | 0.451 | 2

# %% [markdown]
# ### Architecture 200-200-200-200
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.548 | 0.574 | 0.549 | 0.539 | 6
# |ReLU6               |0.547 | 0.570 | 0.547 | 0.538 | 6
# |ELU (1)             |0.545 | 0.571 | 0.546 | 0.534 | 6
# |SELU                |0.545 | 0.574 | 0.545 | 0.533 | 6
# |LReLU               |0.549 | 0.573 | 0.549 | 0.537 | 6
# |Thresholded ReLU (1)|0.306 | 0.338 | 0.305 | 0.289 | 5
# |Swish               |**0.564** | 0.579 | 0.565 | **0.556** | 8
# |Sigmoid             |0.546 | 0.571 | 0.546 | 0.534 | 6
# |Hard sigmoid        |0.536 | 0.559 | 0.537 | 0.523 | 6
# |tanh                |0.540 | 0.564 | 0.540 | 0.526 | 6
# |Hard tanh           |0.529 | 0.547 | 0.530 | 0.516 | 8
# |Rational tanh       |0.550 | 0.575 | 0.550 | 0.538 | 6
# |Rectified tanh      |0.518 | 0.530 | 0.519 | 0.507 | 8
# |Softmax             |0.534 | 0.546 | 0.535 | 0.526 | 8
# |Softplus            |0.558 | 0.580 | 0.559 | 0.548 | 6
# |Softsign            |0.533 | 0.556 | 0.534 | 0.518 | 6
# |sin                 |0.549 | 0.559 | 0.550 | 0.545 | 8
# |cos                 |0.498 | 0.518 | 0.498 | 0.484 | 4
# |exp                 |0.434 | 0.460 | 0.434 | 0.427 | 8
# |pow2                |0.526 | 0.547 | 0.528 | 0.516 | 6
# |pow3                |0.447 | 0.476 | 0.449 | 0.427 | 6
# |gauss               |0.488 | 0.505 | 0.489 | 0.475 | 4

# %% [markdown]
# ### Architecture 300-300-300-300
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.557 | 0.584 | 0.557 | 0.547 | 6
# |ReLU6               |0.561 | 0.582 | 0.561 | 0.550 | 6
# |ELU (1)             |0.562 | 0.587 | 0.562 | 0.551 | 6
# |SELU                |0.546 | 0.578 | 0.546 | 0.532 | 6
# |LReLU               |0.556 | 0.576 | 0.556 | 0.544 | 6
# |Thresholded ReLU (1)|0.335 | 0.371 | 0.333 | 0.321 | 5
# |Swish               |**0.569** | 0.592 | 0.570 | **0.560** | 6 (i 8)
# |Sigmoid             |0.552 | 0.577 | 0.552 | 0.541 | 6
# |Hard sigmoid        |0.538 | 0.560 | 0.538 | 0.526 | 8
# |tanh                |0.545 | 0.561 | 0.546 | 0.536 | 8
# |Hard tanh           |0.531 | 0.550 | 0.531 | 0.519 | 8
# |Rational tanh       |0.548 | 0.572 | 0.549 | 0.537 | 8
# |Rectified tanh      |0.536 | 0.553 | 0.537 | 0.527 | 8
# |Softmax             |0.534 | 0.548 | 0.535 | 0.528 | 8
# |Softplus            |0.567 | 0.592 | 0.568 | 0.555 | 6
# |Softsign            |0.542 | 0.569 | 0.542 | 0.527 | 6
# |sin                 |0.547 | 0.573 | 0.547 | 0.532 | 4
# |cos                 |0.496 | 0.513 | 0.496 | 0.480 | 4
# |exp                 |0.435 | 0.478 | 0.435 | 0.417 | 3 (i 4)
# |pow2                |0.536 | 0.557 | 0.537 | 0.528 | 6
# |pow3                |0.410 | 0.434 | 0.411 | 0.389 | 6
# |gauss               |0.484 | 0.499 | 0.485 | 0.470 | 4

# %% [markdown]
# ### Architecture 500-500-500-500
#
# |Function|Accuracy|Precision|Recall|F1|Best params|
# |:---|---|---|---|---|---:|
# |ReLU                |0.568 | 0.594 | 0.568 | 0.558 | 6
# |ReLU6               |0.554 | 0.578 | 0.554 | 0.545 | 6
# |ELU (1)             |0.563 | 0.593 | 0.564 | 0.552 | 6
# |SELU                |0.555 | 0.589 | 0.555 | 0.544 | 6
# |LReLU               |0.559 | 0.585 | 0.559 | 0.548 | 6
# |Thresholded ReLU (1)|0.381 | 0.421 | 0.380 | 0.367 | 6
# |Swish               |**0.571** | 0.596 | 0.571 | 0.562 | 6
# |Sigmoid             |0.555 | 0.585 | 0.554 | 0.544 | 6
# |Hard sigmoid        |0.544 | 0.574 | 0.544 | 0.530 | 6
# |tanh                |0.544 | 0.566 | 0.544 | 0.531 | 8
# |Hard tanh           |0.531 | 0.551 | 0.532 | 0.519 | 8
# |Rational tanh       |0.549 | 0.574 | 0.548 | 0.537 | 6
# |Rectified tanh      |0.542 | 0.566 | 0.542 | 0.530 | 8
# |Softmax             |0.532 | 0.539 | 0.532 | 0.526 | 8
# |Softplus            |**0.571** | 0.598 | 0.572 | **0.561** | 6
# |Softsign            |0.546 | 0.570 | 0.547 | 0.533 | 8
# |sin                 |0.561 | 0.584 | 0.561 | 0.553 | 3
# |cos                 |0.494 | 0.514 | 0.494 | 0.483 | 4
# |exp                 |0.415 | 0.464 | 0.415 | 0.394 | 3
# |pow2                |0.540 | 0.560 | 0.540 | 0.529 | 6
# |pow3                |0.222 | 0.261 | 0.223 | 0.222 | 8
# |gauss               |0.485 | 0.503 | 0.485 | 0.472 | 4

# %% [markdown]
# ### Architecture 30-30, split 80/20
#
# Best function: <br>
# $\sin (\frac{\sin (x)}{\sin (x)}) \cdot \frac{\sin (x)}{0.3461698400504488}$
#
# Evolution:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.459 | 0.464 | 0.460 | 0.442
#
# Re-tested on official split:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.477 | 0.485 | 0.477 | 0.462

# %%
plot(lambda x: m.sin(1) * m.sin(x)/0.3461698400504488)

# %% [markdown]
# ### Architecture 30-30, split 60/40
#
# Best function: <br>
# $\min (\sin (\sin (x)),x)$
#
# Evolution:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.437 | 0.457 | 0.436 | 0.414
#
# Re-tested on official split:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.462 | 0.489 | 0.463 | 0.441

# %%
plot(lambda x: min(m.sin(m.sin(x)), x))

# %% [markdown]
# ### Architecture 30-30, split 40/60
#
# Best function: <br>
# $\cos (x + 1.0)$
#
# Evolution:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.397 | 0.394 | 0.398 | 0.380
#
# Re-tested on official split:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.437 | 0.436 | 0.437 | 0.420

# %%
plot(lambda x: m.cos(x+1))

# %% [markdown]
# ### Architecture 28-28-28, split 80/20
#
# Best function: <br>
# $\min (\sin (\sin (x)),x)$
#
# Evolution:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.456 | 0.487 | 0.457 | 0.433
#
# Re-tested on official split:
#
# Accuracy | Precision | Recall | F1
# - | - | - | -
# 0.454 | 0.481 | 0.454 | 0.427

# %%
plot(lambda x: min(m.sin(m.sin(x)), x))
